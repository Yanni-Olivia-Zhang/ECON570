# %%
import pandas as pd

# %%
tb1a = pd.read_csv('../patents_data/excel/table_1a.csv')
tb1b = pd.read_csv('../patents_data/excel/table_1b.csv')
tb3 = pd.read_csv('../patents_data/excel/table_3.csv')
#tb2b = pd.read_csv('../patents_data/excel/table_2b.csv')

# %%
tb3
# Out:
#      super_opeid                                             instnm  count  \
# 0              1  University Of Hawaii And Hawaii Community Coll...  27002
# 1              4                   Coast Community College District  24340
# 2             13  Kern & North Orange County Community College D...  18765
# 3             16        San Mateo County Community College District  10936
# 4             19         Foothill-Deanza Community College District  16619
# ..           ...                                                ...    ...
# 418        20662                                    New School, The   2691
# 419        20771                Milwaukee Institute Of Art & Design    640
# 420        20789                         Art Institute Of Colorado    2433
# 421        21415                 Savannah College Of Art And Design   4675
# 422        22913                          Art Institute Of Seattle    2616
#
# ...

# %%
tb1b.head()
# Out:
#     par_state par_stateabbrv  kid_count  inventor   top5cit  inventor_cat_1  \
# 0      Alaska             AK      42265  0.001798  0.000047        0.000095
# 1     Alabama             AL     273721  0.000796  0.000033        0.000088
# 2    Arkansas             AR     162805  0.000792  0.000043        0.000043
# 3     Arizona             AZ     269197  0.002013  0.000089        0.000130
# 4  California             CA    1670537  0.002471  0.000112        0.000160
#
#    inventor_cat_2  inventor_cat_3  inventor_cat_4  inventor_cat_5  ...  \
# 0        0.000639        0.000237        0.000213        0.000213  ...
# 1        0.000285        0.000099        0.000084        0.000066  ...
# 2        0.000184        0.000129        0.000141        0.000080  ...
# 3        0.000728        0.000357        0.000216        0.000212  ...
# 4        0.000919        0.000420        0.000302        0.000188  ...
#
#    inventor_cat_5_pq_5  inventor_cat_6_pq_5  inventor_cat_7_pq_5  \
# ...
